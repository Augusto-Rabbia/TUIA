# %% [markdown]
# # Introducción y carga de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import warnings
# Preprocesado
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
# Regresión logística
from sklearn.linear_model import LogisticRegression
# Métricas
from sklearn.metrics import classification_report, accuracy_score, log_loss
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, roc_auc_score, auc
# Grid search
from sklearn.model_selection import GridSearchCV
# Explicabilidad
import shap
# AutoML
#from pycaret.classification import setup
# Redes neuronales
import tensorflow as tf
# Grid search en TF
import optuna
# MLOps
from sklearn.pipeline import Pipeline
import joblib
import json

# %% [markdown]
# Carga datos de dataset
#
# Contiene aproximadamente 10 años de observaciones diarias de variables climáticas: temperatura, dirección y velocidad del viento, humedad, presión, nubosidad, y cantidad de lluvia en mm.
# Tras observar los datos de un día dado, el objetivo es predecir las variables target:
#
# - RainTomorrow: si el día siguiente llueve o no llueve. Problema de Clasificación.

# %%
df = pd.read_csv('weatherAUS.csv')
df.head(3)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# [3 rows x 23 columns]

# %%
len(df)
# Out:
# 145460

# %% [markdown]
# Seleccionamos 10 ciudades aleatoriamente.

# %%
# Semilla para reproducibilidad
random.seed(42)
ciudades = random.sample(df["Location"].unique().tolist(), 10)
ciudades
# Out:
# ['Perth',
#  'NorfolkIsland',
#  'BadgerysCreek',
#  'MountGinini',
#  'Canberra',
#  'Wollongong',
#  'Penrith',
#  'NorahHead',
#  'Nuriootpa',
#  'Newcastle']

# %% [markdown]
# Veamos los tipos y la cantidad de observaciones.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %% [markdown]
# Vemos que tenemos 22 variables, de las cuales 16 son numéricas, 5 categóricas y fecha será de tipo date. Por otro lado, tenemos la variable Location, que eliminaremos a continuación.
#
# Droppeamos los valores faltantes para la variable objetivo. El resto de valores nulos serán tratados más adelante.

# %%
df = df.dropna(subset=['RainTomorrow']).reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
#  17  Cloud9am       88536 non-null   float64
#  18  Cloud3pm       85099 non-null   float64
#  19  Temp9am        141289 non-null  float64
#  20  Temp3pm        139467 non-null  float64
#  21  RainToday      140787 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.0+ MB

# %%
df = df[df["Location"].isin(ciudades)].reset_index(drop=True).drop(columns=["Location"])
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# # Análisis exploratorio

# %% [markdown]
# ## Visualización de los datos

# %% [markdown]
# Hechemos un vistazo a los datos que contiene nuestro dataframe.

# %%
df_train.head()
# Out:
#              Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 24560  2010-05-29      9.5     12.9      12.0          1.0       3.2
# 16432  2013-11-23     17.8     22.3       6.8          NaN       NaN
# 4400   2013-04-13     14.2     25.5       0.0          NaN       NaN
# 8604   2016-11-30     19.2     25.6       0.0          NaN       NaN
# 7261   2013-01-21     19.9     26.8       3.6          NaN       NaN
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 24560           W           69.0          W        WSW  ...         91.0
# 16432           N           33.0        SSE          E  ...         85.0
# 4400          NaN            NaN        NaN         SE  ...         91.0
# 8604            N           63.0          S          E  ...         70.0
# 7261          ENE           22.0        SSW        ENE  ...         82.0
#
#        Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 24560         89.0       1008.7       1009.8       6.0       8.0      9.6
# 16432         81.0       1005.7       1003.6       NaN       4.0     19.8
# 4400          64.0          NaN          NaN       5.0       1.0     17.0
# 8604          67.0       1012.6       1010.0       NaN       NaN     22.9
# 7261          66.0       1015.8       1013.8       NaN       NaN     24.0
#
#        Temp3pm  RainToday  RainTomorrow
# 24560     12.2        Yes           Yes
# 16432     20.9        Yes            No
# 4400      24.2         No            No
# 8604      24.3         No            No
# 7261      25.8        Yes            No
#
# [5 rows x 22 columns]

# %% [markdown]
# Identificamos los tipos de datos de cada columna, y la cantidad de datos faltantes en cada columna, comparándolo con el tamaño del dataframe.

# %%
df_train.info()
print("\nTamaño del dataframe:")
df_train.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24194 entries, 24560 to 23654
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           24194 non-null  object
#  1   MinTemp        23874 non-null  float64
#  2   MaxTemp        24042 non-null  float64
#  3   Rainfall       23917 non-null  float64
#  4   Evaporation    8526 non-null   float64
#  5   Sunshine       8093 non-null   float64
#  6   WindGustDir    21341 non-null  object
#  7   WindGustSpeed  21356 non-null  float64
#  8   WindDir9am     21399 non-null  object
#  9   WindDir3pm     22708 non-null  object
#  10  WindSpeed9am   23627 non-null  float64
#  11  WindSpeed3pm   23123 non-null  float64
#  12  Humidity9am    23563 non-null  float64
#  13  Humidity3pm    23185 non-null  float64
#  14  Pressure9am    16839 non-null  float64
#  15  Pressure3pm    16868 non-null  float64
#  16  Cloud9am       12322 non-null  float64
#  17  Cloud3pm       11203 non-null  float64
#  18  Temp9am        23677 non-null  float64
#  19  Temp3pm        23269 non-null  float64
#  20  RainToday      23917 non-null  object
#  21  RainTomorrow   24194 non-null  object
# dtypes: float64(16), object(6)
# memory usage: 4.2+ MB
#
# Tamaño del dataframe:
# (24194, 22)

# %% [markdown]
# Algunas medidas de resumen de las variables numéricas de datos.

# %%
df_train.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall  Evaporation     Sunshine  \
# count  23874.000000  24042.000000  23917.000000  8526.000000  8093.000000
# mean      11.651525     21.830634      2.601238     4.998053     7.789374
# std        6.317636      6.875519      8.445802     3.337659     3.662865
# min       -8.500000     -4.800000      0.000000     0.000000     0.000000
# 25%        7.500000     17.900000      0.000000     2.600000     5.300000
# 50%       12.400000     21.700000      0.000000     4.200000     8.500000
# 75%       16.600000     25.800000      0.800000     6.800000    10.600000
# max       29.700000     46.900000    216.300000    74.800000    14.300000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   21356.000000  23627.000000  23123.000000  23563.000000  23185.000000
# mean       39.697649     12.244551     17.044069     71.859950     56.283071
# std        14.486898      9.182497      9.346625     17.722962     20.554315
# min         7.000000      0.000000      0.000000      3.000000      2.000000
# 25%        30.000000      6.000000      9.000000     60.000000     41.000000
# 50%        37.000000     11.000000     17.000000     73.000000     56.000000
# 75%        48.000000     17.000000     22.000000     85.000000     71.000000
# max       135.000000    130.000000     83.000000    100.000000    100.000000
#
#         Pressure9am   Pressure3pm      Cloud9am      Cloud3pm       Temp9am  \
# count  16839.000000  16868.000000  12322.000000  11203.000000  23677.000000
# mean    1018.273484   1015.980318      4.531245      4.551370     16.173561
# std        6.849742      6.691395      2.862065      2.700936      6.082453
# min      982.000000    985.500000      0.000000      0.000000     -7.200000
# 25%     1013.800000   1011.500000      1.000000      2.000000     12.400000
# 50%     1018.300000   1016.000000      5.000000      5.000000     16.800000
# 75%     1022.900000   1020.500000      7.000000      7.000000     20.600000
# max     1040.200000   1037.800000      9.000000      8.000000     39.000000
#
#             Temp3pm
# count  23269.000000
# mean      20.311634
# std        6.695757
# min       -5.400000
# 25%       16.600000
# 50%       20.200000
# 75%       24.200000
# max       46.200000

# %% [markdown]
# ## Gráficos univariados

# %% [markdown]
# Graficamos las diferentes variables del dataframe, para dar un primer pantallazo de nuestro datos, y a su vez, chequeamos el balanceo de las variables.

# %% [markdown]
# ### Variable objetivo - RainTomorrow

# %%
rain_counts = df_train['RainTomorrow'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(rain_counts, labels=rain_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de RainTomorrow')
plt.show()

# %% [markdown]
# Vemos que hay una proporción de 3 a 1 en la variable objetivo, lo cual significa que está desbalanceada. Este problema debe ser considerado a la hora de entrenar al modelo para evitar que se limite a predecir la categoría dominante.

# %% [markdown]
# ### Lluvia

# %% [markdown]
# Buscamos predecir si lloverá un día con los datos de días anteriores. Para esto, es vital que conozcamos cómo se ven estos datos:

# %%
rain_counts = df_train['RainToday'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(rain_counts, labels=rain_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de RainToday')
plt.show()

# %%
plt.hist(df_train.dropna(subset=['Rainfall'])['Rainfall'], bins=50, edgecolor='k', alpha=0.75)
plt.show()

# %%
df_train["Rainfall"].describe()
# Out:
# count    23917.000000
# mean         2.601238
# std          8.445802
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.800000
# max        216.300000
# Name: Rainfall, dtype: float64

# %% [markdown]
# Vemos que tiene una distribución de forma exponencial, con la mayoría de sus valores en 0 (hasta el 3er cuartil, los valores son 0). Esto puede explicarse ya que la mayoría de días no hubo lluvia. Es más, en el anterior gráfico, vimos que el 77% de los días no llovió, por lo que estos resultados son de esperar.

# %% [markdown]
# ### Velocidad del Viento

# %% [markdown]
# Procedemos a graficar otras variables, para conocer cómo se ve nuestra base de datos.

# %%
plt.hist(df_train['WindGustSpeed'], bins=10, edgecolor='k', alpha=0.75)
plt.axvline(df_train['WindGustSpeed'].mean(), color='r', linewidth=2)
plt.axvline(df_train['WindGustSpeed'].median(), color='y', linewidth=2)
plt.legend(['Media', 'Mediana'])
plt.xlabel('Velocidad del Viento')
plt.ylabel('Frecuencia')
plt.title('Histograma de Velocidad del Viento')
plt.show()

# %% [markdown]
# Vemos que la variable tiene una distribución aproximadamente normal y levemente asimétrica hacia la derecha.

# %% [markdown]
# ### Nubes

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
df_train['Cloud9am'].value_counts().sort_index().plot(kind="bar", ax=axes[0], edgecolor='k', alpha=0.7)
axes[0].set_xlabel('Nubes a las 9am')
axes[0].set_ylabel('Frecuencia')
axes[0].set_title('Barplot de Nubes a las 9am')

df_train['Cloud3pm'].value_counts().sort_index().plot(kind="bar", ax=axes[1], edgecolor='k', alpha=0.7)
axes[1].set_xlabel('Nubes a las 3pm')
axes[1].set_ylabel('Frecuencia')
axes[1].set_title('Barplot de Nubes a las 3pm')

plt.show()

# %% [markdown]
# Al ser dos variables similares, es de esperar que sus distribuciones también lo sean, como se puede observar. Por otro lado, esperamos que estén altamente correlacionadas, pero no tiene por qué ser el caso con simplemente ver los gráficos.
#
# A pesar de que inicialmente se importó como float64, la variable es numérica discreta.

# %% [markdown]
# ### Presión

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
df_train['Pressure9am'].plot.hist(ax=axes[0], bins=10, edgecolor='k', alpha=0.7)
axes[0].set_xlabel('Presión a las 9am')
axes[0].set_ylabel('Frecuencia')
axes[0].set_title('Histograma de Presión a las 9am')

df_train['Pressure3pm'].plot.hist(ax=axes[1], bins=10, edgecolor='k', alpha=0.7)
axes[1].set_xlabel('Presión a las 3pm')
axes[1].set_ylabel('Frecuencia')
axes[1].set_title('Histograma de Presión a las 3pm')

plt.show()

# %% [markdown]
# Nuevamente, tenemos que estas dos variables similares tienen una distribución casi idéntica.

# %% [markdown]
# ### Temperatura mínima y máxima

# %%
plt.hist(df_train['MinTemp'], bins=10, edgecolor='k', alpha=0.75, label='MinTemp')
plt.hist(df_train['MaxTemp'], bins=10, edgecolor='k', alpha=0.75, label='MaxTemp')
plt.xlabel('Temperatura')
plt.ylabel('Frecuencia')
plt.title('Histogramas de las Temperaturas Máxima y Mínima')
plt.legend()
plt.show()

# %% [markdown]
# Vemos que la temperatura mínima y máxima siguen distribuciones aproximadamente normales, la primera asimétrica hacia la izquierda y la segunda hacia la derecha. Además podemos observar que, como es esperable, el rango de valores de estas están "desplazados" en el eje.

# %% [markdown]
# ### Dirección del viento

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

df_train["WindDir9am"].value_counts().sort_index().plot(kind="pie", autopct='%1.1f%%', ax=axes[0])
axes[0].set_title('WindDir9am')
axes[0].set_ylabel('')

df_train["WindDir3pm"].value_counts().sort_index().plot(kind="pie", autopct='%1.1f%%', ax=axes[1])
axes[1].set_title('WindDir3pm')
axes[1].set_ylabel('')

plt.show()

# %% [markdown]
# Vemos que la dirección del viento en ambos casos es una variable distribuida de manera casi equitativa, no habiendo ninguna clase con una frecuencia demasiado alta o baja.

# %% [markdown]
# ## Gráficos bivariados

# %% [markdown]
# Veamos cómo afecta la presencia de nubes a la probabilidad de lluvia al día siguiente.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8))

sns.barplot(x='Cloud9am', y='Rainfall', ax=axes[0], data=df_train)
axes[0].set_ylim(0, 7.4)
axes[0].set_title('Cantidad de lluvia al día siguiente según la cantidad de nubes a las 9am')

sns.barplot(x='Cloud3pm', y='Rainfall', ax=axes[1], data=df_train)
axes[1].set_ylim(0, 7.4)
axes[1].set_title('Cantidad de lluvia al día siguiente según la cantidad de nubes a las 3pm')
plt.show()

# %% [markdown]
# Estas variables tienen una aparentemente alta correlación: A medida que aumenta la cantidad de nubes, la cantidad de lluvia observada incrementa.

# %%
# evaporation y maxtemp
plt.scatter(df_train['MaxTemp'], df_train['Humidity3pm'], edgecolor='k', alpha=0.7)
plt.xlabel("Temperatura máxima")
plt.ylabel('Humedad')
plt.show()

# %% [markdown]
# Vemos una tendencia decreciente en la humedad a medida que la temperatura incrementa.

# %% [markdown]
# # Limpieza de los datos

# %% [markdown]
# ## Codificación de variables categóricas

# %% [markdown]
# #### Codificamos RainToday y RainTomorrow

# %%
code_lluvia = {"Yes":1, "No":0}

df_train['RainToday'] = df_train["RainToday"].map(code_lluvia)
df_train['RainTomorrow'] = df_train["RainTomorrow"].map(code_lluvia)

# Lo hacemos en el df de test
df_test['RainToday'] = df_test["RainToday"].map(code_lluvia)
df_test['RainTomorrow'] = df_test["RainTomorrow"].map(code_lluvia)

# %% [markdown]
# Veamos si existe algún desbalanceo en los datos:

# %% [markdown]
# ### Balanceo y formatteo de fechas

# %% [markdown]
# Balanceo de los años

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])
df_train["Year"] = df_train["Date"].dt.year
df_train["Month"] = df_train["Date"].dt.month
nbins = len(df_train["Year"].unique())
df_train['Year'].value_counts().sort_index().plot(kind="bar")

# Hacemos lo mismo en el dataset de test
df_test['Date'] = pd.to_datetime(df_test['Date'])
df_test["Year"] = df_test["Date"].dt.year
df_test["Month"] = df_test["Date"].dt.month
df_test['Year'].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Year'>

# %%
df_train[df_train["RainTomorrow"]==1]["Year"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# Se puede observar que la variable Year no tiene una relevancia mayor en la cantidad de días de lluvia, ya que se puede ver que el barplot es muy similar al anteriomente visto, lo cual nos dice que la cantidad de lluvia en un año depende realmente casi exclusivamente de la cantidad de datos que tengamos del mismo.
#
# Por lo tanto, no consideramos esta variable de relevancia y se la omitirá.

# %%
df_train = df_train.drop(columns=["Year"])

# Hacemos lo mismo en el dataset de test
df_test = df_test.drop(columns=["Year"])

# %% [markdown]
# Balanceo de los meses

# %%
df_train['Month'].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Observamos que existe un buen balanceo de los años y los meses.

# %% [markdown]
# Ahora, podemos finalmente codificar fecha

# %%
# get dummies de mes
df_train = pd.get_dummies(df_train, columns=['Month'], drop_first=True, dtype='int8')

# Hacemos lo mismo en el dataset de test
df_test = pd.get_dummies(df_test, columns=['Month'], drop_first=True, dtype='int8')

# %% [markdown]
# ### Balanceo y formatteo de la dirección del viento

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))  # 1 fila y 3 columnas para los gráficos

df_train['WindGustDir'].value_counts().sort_index().plot(kind="bar", ax=axes[0])
df_train['WindDir9am'].value_counts().sort_index().plot(kind="bar", ax=axes[1])
df_train['WindDir3pm'].value_counts().sort_index().plot(kind="bar", ax=axes[2])

axes[0].set_xlabel('WindGustDir')
axes[1].set_xlabel('WindDir9am')
axes[2].set_xlabel('WindDir3pm')
fig.suptitle('Conteo de direcciones del viento')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Codificamos la dirección del viento

# %% [markdown]
# Pudimos observar que la dirección del viento está relativamente balanceada. Creamos una nueva representacion numérica del viento, y dos columnas para esta nueva representación.

# %%
WindDirToXDir = {
    'N': 0,
    'S': 0,
    'E': 1,
    'W': -1,
    'NW': 2**0.5,
    'NE': -2**0.5,
    'SE': 2**0.5,
    'SW': -2**0.5,
    'NNW': np.cos(5*np.pi/8),
    'NNE': np.cos(3*np.pi/8),
    'ENE': np.cos(1*np.pi/8),
    'WNW': np.cos(7*np.pi/8),
    'ESE': np.cos(-1*np.pi/8),
    'SSE': np.cos(-3*np.pi/8),
    'SSW': np.cos(-5*np.pi/8),
    'WSW': np.cos(-7*np.pi/8)
}
WindDirToYDir = {
    'N': 1,
    'S': -1,
    'E': 0,
    'W': 0,
    'NW': 2**0.5,
    'NE': 2**0.5,
    'SE': -2**0.5,
    'SW': -2**0.5,
    'NNW': np.sin(3*np.pi/8),
    'NNE': np.sin(3*np.pi/8),
    'ENE': np.sin(1*np.pi/8),
    'WNW': np.sin(1*np.pi/8),
    'ESE': np.sin(-1*np.pi/8),
    'SSE': np.sin(-3*np.pi/8),
    'SSW': np.sin(-3*np.pi/8),
    'WSW': np.sin(-1*np.pi/8)
}

df_train['WindDir3pmX'] = df_train['WindDir3pm'].map(WindDirToXDir)
df_train['WindDir3pmY'] = df_train['WindDir3pm'].map(WindDirToYDir)

df_train['WindDir9amX'] = df_train['WindDir9am'].map(WindDirToXDir)
df_train['WindDir9amY'] = df_train['WindDir9am'].map(WindDirToYDir)

df_train['WindGustDirX'] = df_train['WindGustDir'].map(WindDirToXDir)
df_train['WindGustDirY'] = df_train['WindGustDir'].map(WindDirToYDir)

df_train = df_train.drop(columns=['WindDir3pm'])
df_train = df_train.drop(columns=['WindDir9am'])
df_train = df_train.drop(columns=['WindGustDir'])

# Hacemos lo mismo en el dataset de test
df_test['WindDir3pmX'] = df_test['WindDir3pm'].map(WindDirToXDir)
df_test['WindDir3pmY'] = df_test['WindDir3pm'].map(WindDirToYDir)

df_test['WindDir9amX'] = df_test['WindDir9am'].map(WindDirToXDir)
df_test['WindDir9amY'] = df_test['WindDir9am'].map(WindDirToYDir)

df_test['WindGustDirX'] = df_test['WindGustDir'].map(WindDirToXDir)
df_test['WindGustDirY'] = df_test['WindGustDir'].map(WindDirToYDir)

df_test = df_test.drop(columns=['WindDir3pm'])
df_test = df_test.drop(columns=['WindDir9am'])
df_test = df_test.drop(columns=['WindGustDir'])

# %% [markdown]
# ### Droppeamos variable Date

# %% [markdown]
# Finalmente, eliminamos la variable date, pues no estaremos analizando los datos como una serie temporal.

# %%
df_train.drop(columns=["Date"], inplace=True)
df_test.drop(columns=["Date"], inplace=True)

# %% [markdown]
# ## Imputación de datos faltantes

# %% [markdown]
# Veamos la cantidad de valores faltantes.

# %%
df_train.isna().sum()
# Out:
# MinTemp            320
# MaxTemp            152
# Rainfall           277
# Evaporation      15668
# Sunshine         16101
# WindGustSpeed     2838
# WindSpeed9am       567
# WindSpeed3pm      1071
# Humidity9am        631
# Humidity3pm       1009
# Pressure9am       7355
# Pressure3pm       7326
# Cloud9am         11872
# Cloud3pm         12991
# Temp9am            517
# Temp3pm            925
# RainToday          277
# RainTomorrow         0
# Month_2              0
# Month_3              0
# Month_4              0
# Month_5              0
# Month_6              0
# Month_7              0
# Month_8              0
# Month_9              0
# Month_10             0
# Month_11             0
# Month_12             0
# WindDir3pmX       1486
# WindDir3pmY       1486
# WindDir9amX       2795
# WindDir9amY       2795
# WindGustDirX      2853
# WindGustDirY      2853
# dtype: int64

# %% [markdown]
# Vemos que hay valores faltantes en la variable `RainToday`, pero no los hay para `RainTomorrow`. Por lo tanto, podemos utilizar la información del día anterior para obtener si llovió o no

# %%
# Crear una columna temporal con los valores de RainTomorrow desplazados una posición hacia arriba
df_train['RainTomorrow_shifted'] = df_train['RainTomorrow'].shift(1)

# Llenar los valores faltantes en RainToday con los valores de RainTomorrow desplazados
df_train['RainToday'] = df_train['RainToday'].fillna(df_train['RainTomorrow_shifted'])

# Eliminar la columna temporal si ya no es necesaria
df_train = df_train.drop(columns=['RainTomorrow_shifted'])

# Hacemos lo mismo para el conjunto de test
df_test['RainTomorrow_shifted'] = df_test['RainTomorrow'].shift(1)
df_test['RainToday'] = df_test['RainToday'].fillna(df_test['RainTomorrow_shifted'])
df_test = df_test.drop(columns=['RainTomorrow_shifted'])

# %%
df_train['RainToday'].isna().sum()
# Out:
# 0

# %% [markdown]
# Debido a que hay una gran cantidad de datos faltantes, además distribuidos entre diversas variables, eliminarlos significaría una pérdida significativa de información para nuestro modelo.
#
# Por lo tanto, haremos inputación de datos. Utilizaremos KNN ya que probó tener una buena performance en el anterior trabajo práctico.

# %%
imputer = KNNImputer(n_neighbors=5)

df_train_imputed = imputer.fit_transform(df_train.drop(columns=["RainTomorrow"]))

df_train_imputed = pd.DataFrame(df_train_imputed, columns=df_train.drop(columns=["RainTomorrow"]).columns)

df_train_imputed["RainTomorrow"] = df_train.reset_index(drop=True)["RainTomorrow"]

df_train = df_train_imputed

df_train.isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Month_2          0
# Month_3          0
# Month_4          0
# Month_5          0
# Month_6          0
# Month_7          0
# Month_8          0
# Month_9          0
# Month_10         0
# Month_11         0
# Month_12         0
# WindDir3pmX      0
# WindDir3pmY      0
# WindDir9amX      0
# WindDir9amY      0
# WindGustDirX     0
# WindGustDirY     0
# RainTomorrow     0
# dtype: int64

# %%
df_test_imputed = imputer.transform(df_test.drop(columns=["RainTomorrow"]))

df_test_imputed = pd.DataFrame(df_test_imputed, columns=df_test.drop(columns=["RainTomorrow"]).columns)

df_test_imputed["RainTomorrow"] = df_test.reset_index(drop=True)["RainTomorrow"]

df_test = df_test_imputed

df_test.isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Month_2          0
# Month_3          0
# Month_4          0
# Month_5          0
# Month_6          0
# Month_7          0
# Month_8          0
# Month_9          0
# Month_10         0
# Month_11         0
# Month_12         0
# WindDir3pmX      0
# WindDir3pmY      0
# WindDir9amX      0
# WindDir9amY      0
# WindGustDirX     0
# WindGustDirY     0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# # Matriz de correlación

# %% [markdown]
# Veamos la matriz de correlación de nuestro dataframe.

# %%
# No inclimos las variables dummies
corr = df_train[["MinTemp", "MaxTemp", "Rainfall", "Evaporation", "Sunshine",
                 "WindGustSpeed", "WindSpeed9am", "WindSpeed3pm", "Humidity9am",
                 "Humidity3pm", "Pressure9am", "Pressure3pm", "Temp9am", "Temp3pm",
                 "Cloud9am", "Cloud3pm", "RainToday", "RainTomorrow"]].corr(method='pearson').round(3)
plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True, cmap="rocket", center=0)
plt.show()

# %% [markdown]
# Observando la matriz de correlación podemos notar que existen ciertas variables que están altamente relacionadas.
#
# Por ejemplo, MaxTemp y Temp3pm, y MinTemp y Temp9am. Es de esperar que alguna de estas variables vean sus coeficientes muy minimizados con regularización, debido a su alta colinealidad.

# %% [markdown]
# Luego de analizar las relaciones de las variables, verificando cuál es el nivel de correlación de múltiples variables con RainfallTomorrow, e intentamos buscar relaciones adicionales.

# %% [markdown]
# # Estandarización

# %% [markdown]
# Utilizamos un StandardScaler en las variables numéricas

# %%
scaler = StandardScaler()

df_train_numeric = df_train.drop(columns=['WindDir3pmX', 'WindDir3pmY', 'WindDir9amX',
                                          'WindDir9amY', 'WindGustDirX', 'WindGustDirY',
                                          "RainToday", "RainTomorrow",
                                          "Month_2", "Month_3", "Month_4", "Month_5", "Month_6",
                                          "Month_7", "Month_8", "Month_9", "Month_10", "Month_11", "Month_12"
                                          ])

df_train_numeric = pd.DataFrame(scaler.fit_transform(df_train_numeric), columns=df_train_numeric.columns)

df_train = pd.concat([df_train_numeric,
                      df_train[["WindDir3pmX", "WindDir3pmY", "WindDir9amX", "WindDir9amY",
                                "WindGustDirX", "WindGustDirY", "RainToday", "RainTomorrow",
                                "Month_2", "Month_3", "Month_4", "Month_5", "Month_6",
                                "Month_7", "Month_8", "Month_9", "Month_10", "Month_11", "Month_12"]]], axis=1)

df_test_numeric = df_test.drop(columns=['WindDir3pmX', 'WindDir3pmY', 'WindDir9amX',
                                          'WindDir9amY', 'WindGustDirX', 'WindGustDirY',
                                          "RainToday", "RainTomorrow",
                                          "Month_2", "Month_3", "Month_4", "Month_5", "Month_6",
                                          "Month_7", "Month_8", "Month_9", "Month_10", "Month_11", "Month_12"
                                          ])

df_test_numeric = pd.DataFrame(scaler.transform(df_test_numeric), columns=df_test_numeric.columns)

df_test = pd.concat([df_test_numeric,
                      df_test[["WindDir3pmX", "WindDir3pmY", "WindDir9amX", "WindDir9amY",
                               "WindGustDirX", "WindGustDirY", "RainToday", "RainTomorrow",
                               "Month_2", "Month_3", "Month_4", "Month_5", "Month_6",
                               "Month_7", "Month_8", "Month_9", "Month_10", "Month_11", "Month_12"]]], axis=1)

# %% [markdown]
# Verifiquemos la distribución de las variables

# %%
df_train.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  2.419400e+04  2.419400e+04  2.419400e+04  2.419400e+04  2.419400e+04
# mean  -8.869303e-17  2.465490e-16  7.048452e-18 -1.421438e-16 -4.863432e-16
# std    1.000021e+00  1.000021e+00  1.000021e+00  1.000021e+00  1.000021e+00
# min   -3.201555e+00 -3.875657e+00 -3.075479e-01 -1.787838e+00 -2.174980e+00
# 25%   -6.597242e-01 -5.703237e-01 -3.075479e-01 -7.364127e-01 -7.087057e-01
# 50%    1.187114e-01 -1.955606e-02 -3.075479e-01 -1.956795e-01  1.106828e-01
# 75%    7.859418e-01  5.770483e-01 -2.125219e-01  6.003999e-01  7.514077e-01
# max    2.867065e+00  3.647378e+00  2.538511e+01  2.630025e+01  2.230003e+00
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   2.419400e+04  2.419400e+04  2.419400e+04  2.419400e+04  2.419400e+04
# mean   -1.397943e-16 -1.350953e-16 -7.988246e-17  2.496327e-16 -8.061667e-17
# std     1.000021e+00  1.000021e+00  1.000021e+00  1.000021e+00  1.000021e+00
# min    -2.349586e+00 -1.342201e+00 -1.842279e+00 -3.924484e+00 -2.677732e+00
# 25%    -6.841324e-01 -6.832552e-01 -6.465000e-01 -6.249917e-01 -7.048364e-01
# 50%    -1.772553e-01 -1.341334e-01 -1.247055e-01  5.766185e-02 -1.432294e-02
# 75%     4.744439e-01  5.248129e-01  5.492791e-01  7.403154e-01  7.255130e-01
# max     6.919025e+00  1.293497e+01  7.180417e+00  1.593632e+00  2.155862e+00
#
#        ...       Month_3       Month_4       Month_5       Month_6  \
# count  ...  24194.000000  24194.000000  24194.000000  24194.000000
# mean   ...      0.093164      0.078491      0.092957      0.086344
# std    ...      0.290668      0.268948      0.290378      0.280877
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#             Month_7       Month_8       Month_9      Month_10      Month_11  \
# count  24194.000000  24194.000000  24194.000000  24194.000000  24194.000000
# mean       0.083244      0.081301      0.079855      0.083698      0.081962
# std        0.276256      0.273303      0.271073      0.276941      0.274313
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            Month_12
# count  24194.000000
# mean       0.075515
# std        0.264225
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# # Definimos X e y

# %%
X_train_full = df_train.drop(columns=["RainTomorrow"])
y_train_full = df_train["RainTomorrow"]

X_test = df_test.drop(columns=["RainTomorrow"])
y_test = df_test["RainTomorrow"]

# Ahora, creamos conjuntos de validación
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)  # 20% de validación, 80% de entrenamiento

# %% [markdown]
# # Regresión logística

# %%
warnings.filterwarnings('ignore')
model = LogisticRegression(random_state=42, max_iter=1, warm_start=True)
LogisticRegression
# Number of epochs
epochs = 200

# Lists to store loss values
train_losses = []
val_losses = []

# Training loop
for epoch in range(epochs):
    # Fit the model for one iteration
    model.fit(X_train, y_train)

    # Predict probabilities
    y_train_pred = model.predict_proba(X_train)
    y_val_pred = model.predict_proba(X_val)

    # Calculate log loss for both training and validation
    train_loss = log_loss(y_train, y_train_pred)
    val_loss = log_loss(y_val, y_val_pred)

    # Append to the lists
    train_losses.append(train_loss)
    val_losses.append(val_loss)

# %%
# Plot the losses
plt.plot(range(epochs), train_losses, label='Training Loss')
plt.plot(range(epochs), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# El modelo parece estabilizarse a partir de aproximadamente 105 epocas, y no parece haber presencia de overfitting.

# %%
logisticRegModel = LogisticRegression()

logisticRegModel.fit(X_train, y_train)

y_pred = logisticRegModel.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.94      0.89      4630
#          1.0       0.68      0.44      0.53      1419
#
#     accuracy                           0.82      6049
#    macro avg       0.76      0.69      0.71      6049
# weighted avg       0.81      0.82      0.81      6049

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %%
# Obtengo las probabilidades de predicción del modelo
y_probs = logisticRegModel.predict_proba(X_test)[:, 1]

# Calculo la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Consideramos que un buen valor en este problema sería uno que tenga la menor cantidad de falsos negativos (días que llovieron y predijimos que no llovería), ya que consideramos que en el mundo real, el peor caso posible sería predecir que no llovería y que llueva.
#
# Sin embargo, claramente hay que conseguir un balance, ya que con esta regla, simplemente predecir que llueve siempre sería una solución "óptima", pero que no aportaría ningún valor.

# %% [markdown]
# Veamos los thresholds a los que equivalen los valores de la curva roc

# %%
# plot fpr and tpr by thresholds
plt.plot(thresholds, fpr, color='blue', label='FPR')
plt.plot(thresholds, tpr, color='red', label='TPR')
plt.legend()
plt.xlabel('Threshold')
plt.show()

# %% [markdown]
# Observándo el gráfico anterior, tenemos que si utilizamos un threshold de 0.5, tendremos un FPR de ~0.1, y un TPR de ~0.5. Como dijimos, lo ideal sería minimizar los Falsos Negativos (o maximizar los Verdaderos Positivos), por lo que un 50% de tasa de error no sería deseable.
#
# Un buen threshold, con esta consideración, sería de aproximadamente 0.2. En este tendremos un TPR de ~0.8, lo cual es relativamente alto, sin que nuestro FPR sea demasiado alto. De hecho, se nota como esta curva comienza a crecer exponencialmente a luego de este punto.

# %%
indice_threshold_ideal = np.abs(thresholds - 0.2).argmin()
fpr[indice_threshold_ideal], tpr[indice_threshold_ideal]
# Out:
# (0.2680345572354212, 0.7730796335447498)

# %% [markdown]
# # Modelo Base

# %% [markdown]
# Como modelo base, podemos utilizar las variables de mayor correlación según la matriz de correlación.
#
# Utilizaremos las variables con correlación > 0.3:
# - `Sunshine`
# - `Humidity3pm`
# - `Cloud3pm`
#
# Luego, si las nubes y humedad superan un cierto umbral (la media) y la cantidad de sol es menor a cierto otro umbral (1er cuartil), prediciremos que mañana lloverá, y en caso contrario, que no.

# %%
df_train[["Sunshine", "Humidity3pm", "Cloud3pm", "RainToday"]].describe()
# Out:
#            Sunshine   Humidity3pm      Cloud3pm     RainToday
# count  2.419400e+04  2.419400e+04  2.419400e+04  24194.000000
# mean  -1.697502e-16  4.458146e-16 -1.923640e-16      0.232454
# std    1.000021e+00  1.000021e+00  1.000021e+00      0.422406
# min   -2.175396e+00 -2.678002e+00 -2.021027e+00      0.000000
# 25%   -7.139365e-01 -7.048427e-01 -7.272869e-01      0.000000
# 50%    1.161231e-01 -1.423678e-02  1.352061e-01      0.000000
# 75%    7.506028e-01  7.256981e-01  9.976992e-01      0.000000
# max    2.229002e+00  2.156239e+00  1.428946e+00      1.000000

# %%
umbral_humedad = df_train["Humidity3pm"].median()
umbral_nubes = df_train["Cloud3pm"].median()
umbral_sol = df_train["Sunshine"].quantile(0.25)
umbral_lluvia = 1

def basemodel_selector(sunshine, humidity3pm, cloud3pm, RainToday):
    return int(humidity3pm > umbral_humedad and cloud3pm > umbral_nubes and sunshine < umbral_sol)

print(umbral_humedad, umbral_nubes, umbral_sol, umbral_lluvia)
# Out:
# -0.014236778367284342 0.13520614321969643 -0.7139365375220957 1

# %%
y_pred = X_test.apply(lambda row: basemodel_selector(row["Sunshine"], row["Humidity3pm"], row["Cloud3pm"], row["RainToday"]), axis=1)

# confussion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.88      0.86      4630
#          1.0       0.54      0.47      0.50      1419
#
#     accuracy                           0.78      6049
#    macro avg       0.69      0.67      0.68      6049
# weighted avg       0.77      0.78      0.78      6049

# %% [markdown]
# Vemos que nuestro modelo tiene un performance inferior al de la regresión logística. Es claro que nuestro modelo funciona bastante mejor que el azar para predecir días sin lluvia pero es peor para predecir días de lluvia.
#
# Además, es menos flexible al no estar prediciendo probabilidades, y por lo tanto no poder ajustar un umbral de decisión.
#
# No consideramos haber conseguido un buen fitting: para empezar, tenemos un modelo peor en todas las métricas al conseguido con la regresión logística. Nuestro modelo no es capaz de predecir la lluvia en más del 50% de los días en los que llueve. Claramente si ajustamos los umbrales que elegimos podríamos intentar mejorar este modelo, pero a costa de peores predicciones para la clase 0.

# %% [markdown]
# # Tunning de Hiperparámetros

# %% [markdown]
# Realizaremos grid search con validación cruzada con k-folds.
#
# Utilizaremos los siguientes parámetros:
# - `penalty`: Podemos elegir diferentes tipos de regularización, como Ridge, Lasso o Elasticnet.
# - `C`: Probamos diferentes pesos de regularización.
# - `solver`: Podemos elegir diferentes solvers, como liblinear, newton-cg, lbfgs, sag o saga. Diferentes solvers son mejores para datasets de diferentes tamaños y características, y soportan diferentes tipos de regularización.
# - `max_iter`: Elegir una diferente cantidad de iteraciones puede ser bueno para evitar overfitting.
# - `class_weight`: Pues nuestro conjunto de datos está desbalanceado.

# %%
warnings.filterwarnings('ignore')

param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', None],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'lbfgs', 'sag', 'saga'],
    'max_iter': [50, 100, 200, 300],
    'class_weight': [None, 'balanced'],
}

grid_search = GridSearchCV(LogisticRegression(random_state=42, verbose=0), param_grid, cv=5, scoring='balanced_accuracy', n_jobs=-1, verbose=0)
grid_search.fit(X_train_full, y_train_full)
# Out:
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
# ...
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /home/vm11/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1186: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=42), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'class_weight': [None, 'balanced'],
#                          'max_iter': [50, 100, 200, 300],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['liblinear', 'newton-cg', 'lbfgs', 'sag',
#                                     'saga']},
#              scoring='balanced_accuracy')

# %% [markdown]
# Veamos los mejores parámetros y su performance

# %%
grid_search.best_params_
# Out:
# {'C': 0.1,
#  'class_weight': 'balanced',
#  'max_iter': 50,
#  'penalty': 'l2',
#  'solver': 'saga'}

# %% [markdown]
# Llama la atención que el mínimo error se encuentra utilizando tan solo 50 operaciones, mientras que en el primer modelo que hicimos, el error de validación mejoraba hasta aproximadamente las 100 iteraciones, y nunca parecía overfittear.

# %%
best_model_reg_log = grid_search.best_estimator_

y_pred = best_model_reg_log.predict(X_test)
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      4630
#            1       0.50      0.73      0.59      1419
#
#     accuracy                           0.77      6049
#    macro avg       0.70      0.75      0.71      6049
# weighted avg       0.81      0.77      0.78      6049

# %%
# Obtengo las probabilidades de predicción del modelo
y_probs = best_model_reg_log.predict_proba(X_test)[:, 1]

# Calculo la ROC y el AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Observamos que el performance general no parece mejorar demasiado, con un AUC igual al obtenido en el modelo de la sección anterior.

# %% [markdown]
# Veamos los thresholds a los que equivalen los valores de la curva roc

# %%
# plot fpr and tpr by thresholds
plt.plot(thresholds, fpr, color='blue', label='FPR')
plt.plot(thresholds, tpr, color='red', label='TPR')
plt.legend()
plt.xlabel('Threshold')
plt.show()

# %% [markdown]
# Notamos que el modelo tiene un TRP mayor para todos los thresholds, lo cual es deseable en nuestro problema. Sin embargo, esto no es sin tener un FPR mayor.

# %%
indice_threshold_ideal = np.abs(thresholds - 0.45).argmin()
fpr[indice_threshold_ideal], tpr[indice_threshold_ideal]
# Out:
# (0.2712742980561555, 0.7702607470049331)

# %% [markdown]
# El performance parece exactamente igual.
#
# En conclusión, el modelo resultante del grid search, en este caso, mejoró el recall del modelo (que es lo que buscamos priorizar) para el umbral predeterminado de 0.5. Sin embargo, una vez ajustamos el umbral de decisión al que definimos como "óptimo", no se encuentra una diferencia significativa entre los dos modelos, por lo que nuestro modelo no se vio beneficiado.

# %% [markdown]
# Ahora, veamos

# %%
# Graficamos los coeficientes
plt.figure(figsize=(10, 5))
plt.stem(X_train_full.columns, best_model_reg_log.coef_[0])
plt.xticks(rotation=90)
plt.title('Coeficientes')
plt.show()

# %% [markdown]
# # Explicabilidad con SHAP

# %% [markdown]
# ## Explicabilidad global

# %%
variables_prediccion = df_train.drop("RainTomorrow", axis=1).columns

explainer = shap.Explainer(best_model_reg_log, X_train, feature_names=variables_prediccion)
shap_values = explainer(X_test)
shap.plots.beeswarm(shap_values)

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# Vemos que las variables que mayor importancia le da el modelo a la hora de predecir si lloverá o no son:
#
# - Humedad a las 3pm
# - La cantidad de luz de sol
# - Presión a las 3pm
# - La velocidad del viento
# - Si llovió el día anterior
#
# Resulta interesante ver que, a pesar de la presencia de valores muy remotos en la variable, la velocidad del viento recibe un gran peso a la hora de decidir para el modelo, aumentando mucho las probabilidades de lluvia. Además, parece contraintuitivo que nuestro modelo prediga que a más presión a las 3pm, menor será la probabilidad de que llueva mañana.
#
# Finalmente, resulta interesante observar que SHAP, para el caso de la regresión logística, los valores que más aportan a SHAP coinciden con los valores que mayores coeficientes tienen para la regresión logística. Esto tiene sentido pues nuestro modelo le asigna importancia a los atributos a través de sus coeficientes. Entonces, a partir de estos resultados, la magnitud del coeficiente representa a su vez la importancia que se le da a la hora de predecir.

# %% [markdown]
# ## Explicabilidad local

# %% [markdown]
# Veamos algunas predicciones en particular.

# %%
ind = y_test.idxmax()

print(X_test.loc[ind].to_dict(), "\n", y_test[ind])

shap.initjs()
shap.plots.force(shap_values[ind])
# Out:
# {'MinTemp': 0.05449789145085403, 'MaxTemp': -0.4132733174161475, 'Rainfall': 3.9211808160847847, 'Evaporation': -0.4830340107307621, 'Sunshine': 0.27628303531858733, 'WindGustSpeed': -0.7708687455213423, 'WindSpeed9am': 0.30521225376574257, 'WindSpeed3pm': -0.21284843669476156, 'Humidity9am': -0.2831864513583119, 'Humidity3pm': 0.28173717043524327, 'Pressure9am': 0.6368491497017587, 'Pressure3pm': 0.7369571780612553, 'Cloud9am': 1.0492435967414597, 'Cloud3pm': 0.566452673271815, 'Temp9am': 0.19282294508879683, 'Temp3pm': -0.25590670096671214, 'WindDir3pmX': 1.4142135623730951, 'WindDir3pmY': -1.4142135623730951, 'WindDir9amX': 1.4142135623730951, 'WindDir9amY': -1.4142135623730951, 'WindGustDirX': 0.3784698805006562, 'WindGustDirY': 0.39108193250385836, 'RainToday': 1.0, 'Month_2': 0.0, 'Month_3': 0.0, 'Month_4': 0.0, 'Month_5': 0.0, 'Month_6': 1.0, 'Month_7': 0.0, 'Month_8': 0.0, 'Month_9': 0.0, 'Month_10': 0.0, 'Month_11': 0.0, 'Month_12': 0.0}
#  1.0
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i1CBFNO6B9M80O2RAK1VR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.28421747686086896, "outValue": 0.061650786938084234, "link": "identity", "featureNames": ["MinTemp", "MaxTemp", "Rainfall", "Evaporation", "Sunshine", "WindGustSpeed", "WindSpeed9am", "WindSpeed3pm", "Humidity9am", "Humidity3pm", "Pressure9am", "Pressure3pm", "Cloud9am", "Cloud3pm", "Temp9am", "Temp3pm", "WindDir3pmX", "WindDir3pmY", "WindDir9amX", "WindDir9amY", "WindGustDirX", "WindGustDirY", "RainToday", "Month_2", "Month_3", "Month_4", "Month_5", "Month_6", "Month_7", "Month_8", "Month_9", "Month_10", "Month_11", "Month_12"], "features": {"0": {"effect": -0.007104281762154241, "value": 0.05449789145085403}, "1": {"effect": -0.007652844689441572, "value": -0.4132733174161475}, "2": {"effect": 0.41985298592124615, "value": 3.9211808160847847}, "3": {"effect": 0.01864991629046389, "value": -0.4830340107307621}, "4": {"effect": -0.19404884137515135, "value": 0.27628303531858733}, "5": {"effect": -0.39677537934330936, "value": -0.7708687455213423}, "6": {"effect": -0.0021883930747696894, "value": 0.30521225376574257}, "7": {"effect": 0.023770843181854993, "value": -0.21284843669476156}, "8": {"effect": -0.010550379405622099, "value": -0.2831864513583119}
"16": {"effect": -0.08823465192245052, "value": -1.4142135623730951}, "17": {"effect": -0.06701393488154972, "value": 1.4142135623730951}, "18": {"effect": -0.04586491441071106, "value": 0.38268343236508984}, "19": {"effect": 0.05922780181300356, "value": 0.9238795325112866}, "20": {"effect": -0.12901560759161498, "value": -1.4142135623730951}, "21": {"effect": -0.04385930500979048, "value": 1.4142135623730951}, "22": {"effect": -0.10917210123586944, "value": 0.0}, "23": {"effect": -0.1769063739877572, "value": 1.0}, "25": {"effect": -0.007730212322522745, "value": 0.0}, "26": {"effect": -0.039055290013867955, "value": 0.0}, "27": {"effect": -0.03383705917731527, "value": 0.0}, "28": {"effect": -0.0977908332457082, "value": 0.0}, "29": {"effect": -0.0344868711142785, "value": 0.0}, "30": {"effect": -0.04257875322090686, "value": 0.0}, "31": {"effect": -0.0331431986501274, "value": 0.0}, "32": {"effect": -0.014677351303621598, "value": 0.0}, "33": {"effect": 0.006790645038470996, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iJNVGFYGWWQC38HYF9SXM')
#   );
# </script>

# %% [markdown]
# Vemos que en explicabilidad local, se replican los resultados obtenidos en la explicabilidad global.

# %% [markdown]
# # Modelo AutoML

# %%
exp_clf = setup(data=df_train, target='RainTomorrow', session_id=123)
# Out:
# <style type="text/css">
# #T_1decb_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1decb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1decb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1decb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1decb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1decb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1decb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1decb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1decb_row1_col1" class="data row1 col1" >RainTomorrow</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1decb_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1decb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1decb_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1decb_row3_col1" class="data row3 col1" >(24194, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1decb_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1decb_row4_col1" class="data row4 col1" >(24194, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1decb_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1decb_row5_col1" class="data row5 col1" >(16935, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1decb_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1decb_row6_col1" class="data row6 col1" >(7259, 35)</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1decb_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1decb_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1decb_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_1decb_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1decb_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_1decb_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1decb_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_1decb_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1decb_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_1decb_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1decb_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_1decb_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1decb_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_1decb_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1decb_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_1decb_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1decb_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_1decb_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1decb_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_1decb_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1decb_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_1decb_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1decb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1decb_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_1decb_row18_col1" class="data row18 col1" >0525</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Lo deseable es usar como metrica maximizar el recall de la clase 1

best_model = exp_clf.compare_models()
# Out:
# <style type="text/css">
# #T_260bc th {
#   text-align: left;
# }
# #T_260bc_row0_col0, #T_260bc_row0_col2, #T_260bc_row0_col3, #T_260bc_row0_col4, #T_260bc_row0_col5, #T_260bc_row0_col6, #T_260bc_row0_col7, #T_260bc_row1_col0, #T_260bc_row1_col1, #T_260bc_row1_col3, #T_260bc_row1_col4, #T_260bc_row1_col5, #T_260bc_row1_col6, #T_260bc_row2_col0, #T_260bc_row2_col1, #T_260bc_row2_col2, #T_260bc_row2_col3, #T_260bc_row2_col5, #T_260bc_row2_col6, #T_260bc_row2_col7, #T_260bc_row3_col0, #T_260bc_row3_col1, #T_260bc_row3_col2, #T_260bc_row3_col3, #T_260bc_row3_col4, #T_260bc_row3_col7, #T_260bc_row4_col0, #T_260bc_row4_col1, #T_260bc_row4_col2, #T_260bc_row4_col3, #T_260bc_row4_col4, #T_260bc_row4_col5, #T_260bc_row4_col6, #T_260bc_row4_col7, #T_260bc_row5_col0, #T_260bc_row5_col1, #T_260bc_row5_col2, #T_260bc_row5_col3, #T_260bc_row5_col4, #T_260

# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %% [markdown]
# Luego de haber corrido todos los modelos, vemos lo siguiente:
# - Si quisieramos maximizar el Recall como la métrica más importante como veníamos haciendo hasta ahora, el mejor modelo -con una ventaja significativa- es el de `Naive Bayes`.
# - Sin embargo, existen dos modelos que tienen métricas excepcionalmente buenas comparado con los demás: `Gradient Boosting Classifier` y `Light Gradient Boosting Machine`.
#
#
# `Gradient Boosting Classifier` combina múltiples árboles de decisión débiles iterativamente. Al ser un modelo ensamble, quizás alguno de los modelos que incluye resultó muy apropiado en el problema que se nos presentó. Esto además llama la atención ya que el modelo `Decision Tree Classifier` es el modelo con las peores métricas que se encontró, con un Accuracy menor que el dummy.
#
# Por otro lado, `Light Gradient Boosting Machine` no es más que un framework open-source para hacer Gradient Boosting.

# %% [markdown]
# Pudemos ver cómo AutoML permite encontrar modelos con un buen performance sin realizar un trabajo arduo, dando métricas en forma de reporte, incluso permitiendo su comparación de forma fácil e intuitiva.
#
# La barrera de entrada es de hecho tan baja que tuvimos que buscar algunos de los modelos que obtuvieron las mejores métricas y hacernos una idea de por qué tienen un mejor rendimiento. A pesar de esto, fuimos capaces de usar AutoML sin mayores problemas.

# %% [markdown]
# # Redes Neuronales

# %% [markdown]
# Definamos la función para crear una red neuronal

# %%
class NeuralNetwork:
    def __init__(self, epochs=50, batch_size=16, learning_rate=0.01):
        #inicializo algunos parámetros como épocas, batch_size, learning rate
        #(no son necesarios)
        #se puede agregar la cantidad de capas, la cantidad de neuronas por capa (pensando en hacer una clase que pueda ser usada para cualquier caso)
        self.epochs = epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.model = None

    def build_model(self, capas_ocultas):
        capas_ocultas.append(tf.keras.layers.Dense(1, activation='sigmoid'))

        model = tf.keras.models.Sequential(capas_ocultas)

        optimizer = tf.keras.optimizers.Adam(learning_rate=self.learning_rate)
        model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy','recall'])

        self.model = model

    def train(self, X_train, y_train, X_valid, y_valid, early_stopping):
        # simplemente el fit del modelo. Devuelvo la evolución de la función de pérdida, ya que es interesante ver como varía a medida que aumentan las épocas!
        history=self.model.fit(X_train, y_train,
                               validation_data=(X_valid, y_valid),
                               epochs=self.epochs,
                               batch_size=self.batch_size,
                               callbacks=[early_stopping])
        return history.history['loss'], history.history['val_loss']

    def evaluate(self, X_test, y_test):
        ### evalúo en test
        loss, accuracy, recall = self.model.evaluate(X_test, y_test)
        print(f"test accuracy: {accuracy:.4f}\ntest recall: {recall:.4f}")

    def predict(self, X_new):
        ### predicciones
        predictions = self.model.predict(X_new)
        return predictions

# %% [markdown]
# ## Modelo simple con una capa oculta con 5 neuronas

# %%
red_neuronal = NeuralNetwork(epochs=100, batch_size=128, learning_rate=0.01)
red_neuronal.build_model(capas_ocultas=[tf.keras.layers.Dense(5, activation='relu')])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

history = red_neuronal.train(X_train, y_train, X_val, y_val, early_stopping)
# Out:
# Epoch 1/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7738 - loss: 0.4719 - recall: 0.0669 - val_accuracy: 0.8312 - val_loss: 0.3991 - val_recall: 0.4350
# Epoch 2/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8276 - loss: 0.3984 - recall: 0.4618 - val_accuracy: 0.8372 - val_loss: 0.3873 - val_recall: 0.4890
# Epoch 3/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.3863 - recall: 0.4993 - val_accuracy: 0.8347 - val_loss: 0.3853 - val_recall: 0.5101
# Epoch 4/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8409 - loss: 0.3698 - recall: 0.5171 - val_accuracy: 0.8411 - val_loss: 0.3761 - val_recall: 0.5220
# Epoch 99/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8377 - loss: 0.3782 - recall: 0.5224 - val_accuracy: 0.8429 - val_loss: 0.3756 - val_recall: 0.4982
# Epoch 100/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8391 - loss: 0.3747 - recall: 0.5095 - val_accuracy: 0.8396 - val_loss: 0.3760 - val_recall: 0.5266

# %%
plt.plot(history[0], label='train')
plt.plot(history[1], label='validation')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
red_neuronal.evaluate(X_test, y_test)
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8340 - loss: 0.3771 - recall: 0.4937
# test accuracy: 0.8258
# test recall: 0.4778

# %% [markdown]
# Vemos que este modelo tiene un performance relativamente mediocre comparado con la mayoría de los modelos obtenidos en AutoML. Veamos si esto se debe a la arquitectura simple de la red.

# %% [markdown]
# ## Modelo complejo:

# %%
red_neuronal_compleja = NeuralNetwork(epochs=100, batch_size=128, learning_rate=0.01)
red_neuronal_compleja.build_model(capas_ocultas=[tf.keras.layers.Dense(16, activation='relu'),
                                                 tf.keras.layers.Dense(8, activation='relu')])
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

history = red_neuronal_compleja.train(X_train, y_train, X_val, y_val, early_stopping)
# Out:
# Epoch 1/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7863 - loss: 0.4550 - recall: 0.4145 - val_accuracy: 0.8417 - val_loss: 0.3804 - val_recall: 0.4734
# Epoch 2/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8316 - loss: 0.3890 - recall: 0.4738 - val_accuracy: 0.8386 - val_loss: 0.3722 - val_recall: 0.5082
# Epoch 3/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8354 - loss: 0.3789 - recall: 0.4904 - val_accuracy: 0.8403 - val_loss: 0.3713 - val_recall: 0.4679
# Epoch 4/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8401 - loss: 0.3678 - recall: 0.4873 - val_accuracy: 0.8427 - val_loss: 0.3727 - val_recall: 0.5119
# Epoch 5/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8395 - loss: 0.3681 - recall: 0.5029 - val_accuracy: 0.8396 - val_loss: 0.3716 - val_recall: 0.4414
# Epoch 6/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8425 - loss: 0.3623 - recall: 0.4929 - val_accuracy: 0.8386 - val_loss: 0.3698 - val_recall: 0.5110
# Epoch 7/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8421 - loss: 0.3673 - recall: 0.5210 - val_accuracy: 0.8380 - val_loss: 0.3718 - val_recall: 0.5119
# Epoch 8/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8415 - loss: 0.3655 - recall: 0.4974 - val_accuracy: 0.8452 - val_loss: 0.3689 - val_recall: 0.4808
# Epoch 9/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8398 - loss: 0.3708 - recall: 0.4946 - val_accuracy: 0.8434 - val_loss: 0.3691 - val_recall: 0.5174
# Epoch 10/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8449 - loss: 0.3651 - recall: 0.5150 - val_accuracy: 0.8411 - val_loss: 0.3707 - val_recall: 0.5092
# Epoch 11/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8464 - loss: 0.3616 - recall: 0.5226 - val_accuracy: 0.8407 - val_loss: 0.3731 - val_recall: 0.4570
# Epoch 12/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.3522 - recall: 0.5274 - val_accuracy: 0.8458 - val_loss: 0.3658 - val_recall: 0.4716
# Epoch 13/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8479 - loss: 0.3534 - recall: 0.5090 - val_accuracy: 0.8425 - val_loss: 0.3713 - val_recall: 0.4853
# Epoch 14/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.3541 - recall: 0.5204 - val_accuracy: 0.8398 - val_loss: 0.3712 - val_recall: 0.5211
# Epoch 15/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8503 - loss: 0.3563 - recall: 0.5341 - val_accuracy: 0.8423 - val_loss: 0.3703 - val_recall: 0.5357
# Epoch 16/100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8585 - loss: 0.3304 - recall: 0.5627 - val_accuracy: 0.8400 - val_loss: 0.3863 - val_recall: 0.5165

# %%
plt.plot(history[0], label='train')
plt.plot(history[1], label='validation')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
red_neuronal_compleja.evaluate(X_test, y_test)
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8399 - loss: 0.3785 - recall: 0.4963
# test accuracy: 0.8314
# test recall: 0.4792

# %% [markdown]
# En esta red neuronal más compleja, vemos que el modelo tiene un error de validación levemente más errático y resulta más propenso a overfitting, con un error de validación que comienza a crecer a partir de la décima iteración de manera consistente y rápida, y un error de entrenamiento un 10% menor que el del modelo anterior.
#
# El fitting obtenido para ambos modelos es marginalmente superior al de la regresión logística, con la desventaja de que el modelo es más costoso para entrenar y predecir.

# %% [markdown]
# ## Grid Search de parámetros

# %%
def objective(trial):

    num_layers = trial.suggest_int('num_layers', 1, 3)
    model = tf.keras.models.Sequential()

    for i in range(num_layers):
        num_units = trial.suggest_int(f'n_units_layer_{i}', 4, 32) # la cantidad de neuronas de cada capa tambien se puede pasar como hiperparámetro
        # activations = trial.suggest_categorical(f'')
        model.add(tf.keras.layers.Dense(num_units, activation='relu')) # capas densas con activacion ReLU

    # capa de salida
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    # compilar
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'recall'])

    # early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    # entrenar
    model.fit(X_train, y_train, validation_data=(X_val, y_val),
              callbacks=[early_stopping],
              batch_size=32, verbose=0)

    # evaluar
    score = model.evaluate(X_val, y_val, verbose=0)
    return score[2] # maximizamos el recall

# crear un estudio de Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# obtener los mejores hiperparámetros
best_params = study.best_params
print("Best parámetros encontrados:", best_params)
# Out:
# [I 2024-11-27 22:29:31,555] A new study created in memory with name: no-name-4063ca9e-f93b-4a17-8285-35e936e8328b
# [I 2024-11-27 22:29:41,424] Trial 0 finished with value: 0.40018314123153687 and parameters: {'num_layers': 3, 'n_units_layer_0': 22, 'n_units_layer_1': 26, 'n_units_layer_2': 5}. Best is trial 0 with value: 0.40018314123153687.
# [I 2024-11-27 22:29:49,123] Trial 1 finished with value: 0.4771062135696411 and parameters: {'num_layers': 2, 'n_units_layer_0': 23, 'n_units_layer_1': 29}. Best is trial 1 with value: 0.4771062135696411.
# [I 2024-11-27 22:29:56,662] Trial 2 finished with value: 0.46978020668029785 and parameters: {'num_layers': 3, 'n_units_layer_0': 6, 'n_units_layer_1': 12, 'n_units_layer_2': 14}. Best is trial 1 with value: 0.4771062135696411.
# [I 2024-11-27 22:30:01,554] Trial 3 finished with value: 0.47252747416496277 and parameters: {'num_layers': 2, 'n_units_layer_0': 17, 'n_units_layer_1': 15}. Best is trial 1 with value: 0.4771062135696411.
# [I 2024-11-27 22:30:13,460] Trial 4 finished with value: 0.4761904776096344 and parameters: {'num_layers': 3, 'n_units_layer_0': 9, 'n_units_layer_1': 12, 'n_units_layer_2': 5}. Best is trial 1 with value: 0.4771062135696411.
# [I 2024-11-27 22:30:17,752] Trial 5 finished with value: 0.5274725556373596 and parameters: {'num_layers': 1, 'n_units_layer_0': 31}. Best is trial 5 with value: 0.5274725556373596.
# [I 2024-11-27 22:30:23,702] Trial 6 finished with value: 0.0 and parameters: {'num_layers': 2, 'n_units_layer_0': 4, 'n_units_layer_1': 14}. Best is trial 5 with value: 0.5274725556373596.
. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:32:30,142] Trial 28 finished with value: 0.48076921701431274 and parameters: {'num_layers': 1, 'n_units_layer_0': 14}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:32:35,743] Trial 29 finished with value: 0.4908424913883209 and parameters: {'num_layers': 2, 'n_units_layer_0': 22, 'n_units_layer_1': 28}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:32:42,869] Trial 30 finished with value: 0.5045787692070007 and parameters: {'num_layers': 3, 'n_units_layer_0': 26, 'n_units_layer_1': 32, 'n_units_layer_2': 29}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:32:49,428] Trial 31 finished with value: 0.5100732445716858 and parameters: {'num_layers': 2, 'n_units_layer_0': 28, 'n_units_layer_1': 26}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:32:56,492] Trial 32 finished with value: 0.4890109896659851 and parameters: {'num_layers': 2, 'n_units_layer_0': 30, 'n_units_layer_1': 23}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:01,623] Trial 33 finished with value: 0.4899267256259918 and parameters: {'num_layers': 2, 'n_units_layer_0': 24, 'n_units_layer_1': 19}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:08,257] Trial 34 finished with value: 0.488095223903656 and parameters: {'num_layers': 2, 'n_units_layer_0': 27, 'n_units_layer_1': 25}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:15,151] Trial 35 finished with value: 0.4606226980686188 and parameters: {'num_layers': 3, 'n_units_layer_0': 30, 'n_units_layer_1': 21, 'n_units_layer_2': 32}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:20,134] Trial 36 finished with value: 0.49542123079299927 and parameters: {'num_layers': 1, 'n_units_layer_0': 21}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:27,120] Trial 37 finished with value: 0.4899267256259918 and parameters: {'num_layers': 3, 'n_units_layer_0': 23, 'n_units_layer_1': 29, 'n_units_layer_2': 24}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:33,694] Trial 38 finished with value: 0.528388261795044 and parameters: {'num_layers': 2, 'n_units_layer_0': 27, 'n_units_layer_1': 18}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:40,134] Trial 39 finished with value: 0.5054945349693298 and parameters: {'num_layers': 1, 'n_units_layer_0': 9}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:46,799] Trial 40 finished with value: 0.5448718070983887 and parameters: {'num_layers': 2, 'n_units_layer_0': 29, 'n_units_layer_1': 17}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:53,016] Trial 41 finished with value: 0.4395604431629181 and parameters: {'num_layers': 2, 'n_units_layer_0': 29, 'n_units_layer_1': 18}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:33:59,696] Trial 42 finished with value: 0.5183150172233582 and parameters: {'num_layers': 2, 'n_units_layer_0': 31, 'n_units_layer_1': 16}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:04,496] Trial 43 finished with value: 0.48351648449897766 and parameters: {'num_layers': 2, 'n_units_layer_0': 32, 'n_units_layer_1': 13}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:16,427] Trial 44 finished with value: 0.5100732445716858 and parameters: {'num_layers': 3, 'n_units_layer_0': 28, 'n_units_layer_1': 10, 'n_units_layer_2': 22}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:25,497] Trial 45 finished with value: 0.47161170840263367 and parameters: {'num_layers': 1, 'n_units_layer_0': 26}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:30,401] Trial 46 finished with value: 0.43223443627357483 and parameters: {'num_layers': 2, 'n_units_layer_0': 31, 'n_units_layer_1': 18}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:37,143] Trial 47 finished with value: 0.4761904776096344 and parameters: {'num_layers': 2, 'n_units_layer_0': 30, 'n_units_layer_1': 10}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:40,899] Trial 48 finished with value: 0.488095223903656 and parameters: {'num_layers': 1, 'n_units_layer_0': 27}. Best is trial 21 with value: 0.5769230723381042.
# [I 2024-11-27 22:34:51,757] Trial 49 finished with value: 0.49450549483299255 and parameters: {'num_layers': 2, 'n_units_layer_0': 29, 'n_units_layer_1': 20}. Best is trial 21 with value: 0.5769230723381042.
# Best parámetros encontrados: {'num_layers': 2, 'n_units_layer_0': 28, 'n_units_layer_1': 23}

# %%
# mostrar mejor resultado
study.best_trial
# Out:
# FrozenTrial(number=21, state=TrialState.COMPLETE, values=[0.5769230723381042], datetime_start=datetime.datetime(2024, 11, 27, 22, 31, 45, 409671), datetime_complete=datetime.datetime(2024, 11, 27, 22, 31, 52, 45037), params={'num_layers': 2, 'n_units_layer_0': 28, 'n_units_layer_1': 23}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'num_layers': IntDistribution(high=3, log=False, low=1, step=1), 'n_units_layer_0': IntDistribution(high=32, log=False, low=4, step=1), 'n_units_layer_1': IntDistribution(high=32, log=False, low=4, step=1)}, trial_id=21, value=None)

# %% [markdown]
# Observamos que el mejor modelo obtenido por optuna produjo un modelo incluso más complejo que los que evaluamos anteriormente. Este lleva a obtener el mayor recall que obtuvimos hasta el momento, a excepción del obtenido por Naive Bayes de la sección AutoML.
#
# Veamos si el resto de métricas son mejores o no que el modelo de Naive Bayes.

# %%
best_nn = NeuralNetwork(epochs=100, batch_size=32)
best_nn.build_model(capas_ocultas=[tf.keras.layers.Dense(28, activation='relu'),
                                    tf.keras.layers.Dense(23, activation='relu')])
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = best_nn.train(X_train, y_train, X_val, y_val, early_stopping)
# Out:
# Epoch 1/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8156 - loss: 0.4147 - recall: 0.4442 - val_accuracy: 0.8357 - val_loss: 0.3896 - val_recall: 0.5833
# Epoch 2/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8378 - loss: 0.3774 - recall: 0.5081 - val_accuracy: 0.8440 - val_loss: 0.3718 - val_recall: 0.4789
# Epoch 3/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8379 - loss: 0.3767 - recall: 0.5031 - val_accuracy: 0.8425 - val_loss: 0.3702 - val_recall: 0.5037
# Epoch 4/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8413 - loss: 0.3684 - recall: 0.4891 - val_accuracy: 0.8390 - val_loss: 0.3722 - val_recall: 0.5549
# Epoch 5/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8452 - loss: 0.3681 - recall: 0.5221 - val_accuracy: 0.8417 - val_loss: 0.3721 - val_recall: 0.4551
# Epoch 6/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8401 - loss: 0.3690 - recall: 0.4934 - val_accuracy: 0.8400 - val_loss: 0.3770 - val_recall: 0.5256
# Epoch 7/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8440 - loss: 0.3640 - recall: 0.5268 - val_accuracy: 0.8438 - val_loss: 0.3753 - val_recall: 0.4716
# Epoch 8/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8438 - loss: 0.3590 - recall: 0.5174 - val_accuracy: 0.8398 - val_loss: 0.3691 - val_recall: 0.5201
# Epoch 9/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8501 - loss: 0.3539 - recall: 0.5282 - val_accuracy: 0.8380 - val_loss: 0.3790 - val_recall: 0.5586
# Epoch 10/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8578 - loss: 0.3428 - recall: 0.5523 - val_accuracy: 0.8380 - val_loss: 0.3778 - val_recall: 0.4963
# Epoch 11/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8511 - loss: 0.3499 - recall: 0.5330 - val_accuracy: 0.8427 - val_loss: 0.3750 - val_recall: 0.4881
# Epoch 12/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8548 - loss: 0.3446 - recall: 0.5311 - val_accuracy: 0.8417 - val_loss: 0.3728 - val_recall: 0.4936
# Epoch 13/100
# 605/605 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8527 - loss: 0.3491 - recall: 0.5426 - val_accuracy: 0.8396 - val_loss: 0.3781 - val_recall: 0.4817

# %%
plt.plot(history[0], label='train')
plt.plot(history[1], label='validation')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# A primera vista, el error de validación (binary-crossentropy) no es mejor que el obtenido por los anteriores modelos. Veamos las métricas restantes del modelo.

# %%
best_nn.evaluate(X_test, y_test)
# Out:
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8384 - loss: 0.3774 - recall: 0.5043
# test accuracy: 0.8337
# test recall: 0.4947

# %% [markdown]
# Vemos que el modelo que en teoría daba el mejor resultado según optuna nos dió esta vez métricas pobres. Esto puede deberse a la aleatoriedad que viene con el entrenamiento de modelos con gradiente descendiente (particularmente modelos que utilizan mini-batch).
#
# Por lo tanto, es posible que el modelo obtenido por optuna haya obtenido un buen performance más por haber "probado muchas veces" hasta obtener un modelo con un recall alto de forma aleatoria, más que por haber realmente encontrado los parámetros que resultan en el mejor modelo.
#
# Por otro lado, resulta interesante observar durante toda esta sección de redes neuronales, que el accuracy y recall de nuestros modelos se correlacionaba poco con la función objetivo de la red neuronal (binary-crossentropy), con estos últimos haciendo grandes saltos incluso cuando la función objetivo parecía estabilizarse.
#
# Estas últimas son algunas de las mayores diferencias con los modelos de regresión logística: esos modelos obtenían métricas generalmente similares entre sí en cada entrenamiento. Por otro lado, otro dato interesante es el hecho que las métricas (tanto de entrenamiento como validación) se estabilizaban luego de ~30 épocas, y se mantenían estables por otras cientos de épocas. Esto no ocurrió en el caso de las redes neuronales, en donde el error de validación tenía un comportamiento errático y una tendencia a overfitting luego de pocas épocas.

# %% [markdown]
# ## Explicabilidad con SHAP

# %% [markdown]
# ### Explicabilidad global

# %%
variables_prediccion = df_train.drop("RainTomorrow", axis=1).columns

explainer = shap.Explainer(best_nn.model, X_train, feature_names=variables_prediccion)
shap_values = explainer(X_test)
shap.plots.beeswarm(shap_values)
# Out:
# PermutationExplainer explainer: 6050it [05:47, 17.39it/s]

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# Notamos que el modelo de redes neuronales le da un mayor peso a clases similares al modelo de regresión logística. Sin embargo, mientras que comparten que la variable `Humidity3pm` es la de mayor peso, las variables en la 2da, 3ra y 4ta posición están intercambiadas, y luego en ambos casos se sigue por `Temp9am`
#
# Esto nos dice que estos dos modelos concluyen con que las variables de mayor importancia son las mismas:
# - `Humidity3pm`
# - `WindGustSpeed`
# - `Pressure3pm`
# - `Sunshine`
# - `Temp9am`

# %% [markdown]
# ### Explicabilidad local

# %%
ind = y_test.idxmax()

print(X_test.loc[ind].to_dict(), "\n", y_test[ind])

shap.initjs()
shap.plots.force(shap_values[ind])
# Out:
# {'MinTemp': 0.05457083267401711, 'MaxTemp': -0.4133239751475853, 'Rainfall': 3.9211808160847847, 'Evaporation': -0.4830340107307621, 'Sunshine': 0.27628303531858733, 'WindGustSpeed': -0.7709762280115019, 'WindSpeed9am': 0.3052216756782678, 'WindSpeed3pm': -0.21269865414563535, 'Humidity9am': -0.2834860490874092, 'Humidity3pm': 0.281723575447119, 'Pressure9am': 0.6368491497017587, 'Pressure3pm': 0.7369571780612553, 'Cloud9am': 1.0492
"value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iQ6L6GT6MJXK87AU5BHXT')
#   );
# </script>

# %% [markdown]
# Para explicabilidad local, tomamos las mismas observaciones. Los resultados de la explicabilidad global nuevamente se replican en la explicabilidad local, pero en este caso, se ve que la segunda observación que tomamos obtuvo una predicción errónea por parte de nuestro modelo.

# %% [markdown]
# Finalmente, cabe destacar que en este caso, SHAP nos aporta información que podría tener más valor que en el de la regresión logística, ya que en este último, podemos obtener la importancia dada a cada variable por parte del modelo simplemente con sus coeficientes. Por otro lado, una red neuronal, al ser un modelo de caja negra, resulta mucho más difícil entender cómo el modelo toma sus decisiones.

# %% [markdown]
# # Comparación de modelos

# %% [markdown]
# Luego de haber creado múltiples modelos para resolver el mismo problema, podemos elegir el modelo que mejor se alinee con nuestros objetivos.
#
# Dado que nuestro objetivo primordial es asegurar, en la medida de lo posible, al usuario que si le comunicamos que no lloverá, en efecto no llueva. Es decir, minimizar los falsos negativos, utilizaremos el Recall como la métrica para evaluar el performance.
#
# Siguiendo esta regla, el modelo que mejor performance obtuvo en nuestros experimentos fue el de Regresión logística obtenido del tuning de hiperparámetros, que obtuvo un recall 0.73, pero además, un accuracy aceptable de 0.77.
#
# Por otro lado, una característica que no puede verse en las métricas pero que podría resultar de interés es el hecho que la regresión logística es un modelo liviano, rápido y estable, lo que puede tener un gran valor a la hora de la puesta en producción.

# %% [markdown]
# # Guardando los modelos para MLOps

# %% [markdown]
# Ahora que tenemos modelos entrenados, los guardamos para poder utilizarlos.

# %%
pipeline = Pipeline(steps=[('imputer', imputer), ('scaler', scaler), ('model', best_model_reg_log)])

# %%
with open("code_lluvia.json", "w") as f:
    json.dump(code_lluvia, f)
with open("WindDirToXDir.json", "w") as f:
    json.dump(WindDirToXDir, f)
with open("WindDirToYDir.json", "w") as f:
    json.dump(WindDirToYDir, f)



joblib.dump(pipeline, "pipeline.joblib")
# Out:
# ['pipeline.joblib']

# %% [markdown]
# # Conclusión

# %% [markdown]
# Este trabajo nos sirve como una buena base para comenzar a comprender temas complejos como redes neuronales, comenzando desde un algoritmo más "sencillo" como regresión logística y comparándolo con un modelo base, para finalmente entrar en las complejidades que rodean a las redes neuronales con tensorflow.
#
# Permite conocer la importancia que tiene tener en cuenta el balance entre las distintas clases, el uso de las métricas correctas así como conocer cuál es relevante para los objetivos que se tienen y la correcta separación de los conjuntos de test, entrenamiento y validación durante todo el desarrollo para que nuestras predicciones se ajusten lo mejor posible a la realidad y que la validación sea realmente efectiva.
#
# Por otro lado, vimos que librerías muy poderosas como pycaret nos permiten entrenar, evaluar y comparar decenas de modelos distintos con una simple línea de código, y elegir el que mejor se adapte a los requerimientos en base a las métricas de cada uno de ellos.
#
# También fue importante la incorporación de SHAPLEY para obtener explicabilidad de los modelos, muy especialmente en redes neuronales (puesto que tienden a funcionar más como "cajas negras" que la regresión logística, por ejemplo), ya que eso nos permite conocer si los modelos utilizan las variables de una manera que se asemeje a nuestras intuiciones o si hay algún problema en el entrenamiento.
#
# Vimos también que el cómo se haga la limpieza de los datos puede tener tanta o más importancia que la selección del modelo utilizado para predecir en sí mismo.
#
# En resumen, este trabajo nos ha permitido no solo profundizar en las bases de los algoritmos de aprendizaje automático, sino también entender la importancia de un enfoque integral que abarque desde la preparación de los datos hasta la interpretación de los modelos, sentando las bases para enfrentar problemas más complejos con herramientas robustas y prácticas efectivas.
